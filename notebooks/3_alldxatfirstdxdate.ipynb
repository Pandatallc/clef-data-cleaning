# %%
import pandas as pd
import numpy as np
from datetime import datetime
from typing import Sequence, List, Tuple

# %%
# pull in only relevant data for development.
raw = pd.read_excel("../data/raw/MASTER FILE.xlsx", 
sheet_name="All MEDs", 
index_col=0,
header=0)

# %%
raw.dropna(how="all", axis=1, inplace=True)

# %%
raw.reset_index()
# Out:
#              MRN                                         BRAND_NAME  \
# 0        2827913                                     thyroid tablet
# 1        2827913  BUTALBITAL-ACETAMINOPHEN-CAFFEINE 50 MG-325 MG...
# 2        2827913    IPRATROPIUM BROMIDE 21 MCG (0.03 %) NASAL SPRAY
# 3        2827913  ALBUTEROL SULFATE HFA 90 MCG/ACTUATION AEROSOL...
# 4        2827913                          ALPRAZolam tablet (XANAX)
# ...          ...                                                ...
# 138960  89183758              acetaminophen 650 mg tab(s) (TYLENOL)
# 138961  89183758                  iv contrast (radiology procedure)
# 138962  89183758                keTORolac 15 mg injection (TORADOL)
# 138963  89183758                        NaCl 0.9% 1,000 mL iv bolus
# 138964  89183758                         BENZONATATE 100 MG CAPSULE
#
#                                              GENERIC_NAME  \
# 0                            thyroid (pork) 120 mg tablet
# 1       butalbital-acetaminophen-caffeine 50 mg-325 mg...
# 2         ipratropium bromide 21 mcg (0.03 %) nasal spray
# 3       albuterol sulfate HFA 90 mcg/actuation aerosol...
# 4                               ALPRAZolam 0.25 mg tablet
# ...                                                   ...
# 138960                        acetaminophen 325 mg tablet
# 138961                                                NaN
# 138962       ketorolac 30 mg/mL (1 mL) injection solution
# 138963         sodium chloride 0.9 % intravenous solution
# 138964                         benzonatate 100 mg capsule
#
#                                               Pharm_Class  \
# 0                                        THYROID HORMONES
# 1       ANALGESIC,NON-SALICYLATE,BARBITURATE,XANTHINE ...
# 2                   NOSE PREPARATIONS, MISCELLANEOUS (RX)
# 3           BETA-ADRENERGIC AGENTS, INHALED, SHORT ACTING
# 4                          ANTI-ANXIETY - BENZODIAZEPINES
# ...                                                   ...
# 138960              ANALGESIC/ANTIPYRETICS,NON-SALICYLATE
# 138961              CARDIOVASCULAR DIAGNOSTICS-RADIOPAQUE
# 138962  NSAIDS, CYCLOOXYGENASE INHIBITOR - TYPE ANALGE...
# 138963                         SODIUM/SALINE PREPARATIONS
# 138964                           ANTITUSSIVES, NON-OPIOID
#
#                                           Pharm_Sub_Class  \
# 0              Thyroid Hormones - Animal Source (Porcine)
# 1       Analgesic or Antipyretic Non-Opioid/Sedative C...
# 2                                  Nasal Anticholinergics
# 3       Asthma/COPD Therapy - Beta 2-Adrenergic Agents...
# 4                     Antianxiety Agent - Benzodiazepines
# ...                                                   ...
# 138960                Analgesic or Antipyretic Non-Opioid
# 138961                Contrast Media - Iodinated Nonionic
# 138962        NSAID Analgesics (COX Non-Specific) - Other
# 138963                          Minerals and Electrolytes
# 138964                          Antitussives - Non-Opioid
#
#                     Thera_Class                                     Route  \
# 0                 THYROID PREPS                                      ORAL
# 1                    ANALGESICS                                      ORAL
# 2                    EENT PREPS                                     NASAL
# 3                ANTIASTHMATICS                                INHALATION
# 4       PSYCHOTHERAPEUTIC DRUGS                                      ORAL
# ...                         ...                                       ...
# 138960               ANALGESICS                                      ORAL
# 138961               DIAGNOSTIC                                       NaN
# 138962               ANALGESICS  INJECTION(UNSPECIFIED PARENTERAL ROUTES)
# 138963        ELECT/CALORIC/H2O                               INTRAVENOUS
# 138964  COUGH/COLD PREPARATIONS                                      ORAL
#
#              ORDERING_TIME   End_Date         DISCON_TIME  \
# 0      2016-06-28 18:54:00 2017-01-09 2017-01-09 21:18:00
# 1      2016-06-30 14:32:00 2017-12-07 2017-12-07 12:46:00
# 2      2016-06-30 14:33:00 2017-09-06 2017-09-06 21:04:00
# 3      2016-08-10 18:08:00 2019-08-22 2019-08-22 16:21:00
# 4      2016-08-12 15:45:00 2017-10-20 2017-10-20 20:39:00
# ...                    ...        ...                 ...
# 138960 2022-01-15 12:46:00 2022-01-15                 NaT
# 138961 2022-01-15 12:46:00 2022-01-15 2022-01-15 22:20:00
# 138962 2022-01-15 12:46:00 2022-01-15                 NaT
# 138963 2022-01-15 12:46:00 2022-01-15                 NaT
# 138964 2022-01-15 14:56:00 2022-01-20                 NaT
#
#                                                       SIG
# 0                      Take 1 tablet by mouth once daily.
# 1       Take 1 tablet by mouth every 4 hours as needed...
# 2       Use 2 Sprays in the nose three times daily as ...
# 3       Inhale 2 Puffs as instructed every 4 hours as ...
# 4            Take 1 tablet by mouth at bedtime as needed.
# ...                                                   ...
# 138960                                                NaN
# 138961                                                NaN
# 138962                                                NaN
# 138963                                                NaN
# 138964  Take 1 capsule by mouth three times daily as n...
#
# [138965 rows x 11 columns]

# %%
raw.reset_index().to_csv("../data/interim/allmeds.csv", index=False)
