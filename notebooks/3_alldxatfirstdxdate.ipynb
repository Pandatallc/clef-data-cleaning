# %% [markdown]
# ### environment

# %%
# environment
import os
import sys
root_path = os.path.abspath("../")
sys.path.append(root_path)

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from typing import Sequence, List, Tuple

# %%
s = pd.read_excel("../data/raw/ccf_apellis_data_cleaning_summary_20231206.xlsx")

# %%
s = pd.read_excel("../data/raw/ccf_apellis_data_cleaning_summary_20231206.xlsx", 
                  sheet_name="PAT_POP_ALCOHOL_OZ_PER_WK", 
                  header=3, 
                  usecols="A:D").iloc[:41]

# %%
s
# Out:
#       Value  Occurrences  Rule (to be defined by CCF team)  \
# 0       1.5           18                              1.50
# 1         1           15                              1.00
# 2         6           12                              6.00
# 3         3            9                              3.00
# 4        .6            7                              0.60
# 5        .5            6                              0.50
# 6      10.5            6                             10.50
# 7        10            6                             10.00
# 8         2            5                              2.00
# 9       4.5            4                              4.50
# 10       18            4                             18.00
# 11       21            4                             21.00
# 12      1.2            4                              1.20
# 13        7            4                              7.00
# 14       15            3                             15.00
# ...
