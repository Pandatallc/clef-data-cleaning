# %% [markdown]
# ### environment

# %%
# environment
import os
import sys
root_path = os.path.abspath("../")
sys.path.append(root_path)

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from typing import Sequence, List, Tuple

# %%
s = pd.read_excel("../data/raw/ccf_apellis_data_cleaning_summary_20231205.xlsx")

# %%
s = pd.read_excel("../data/raw/ccf_apellis_data_cleaning_summary_20231205.xlsx", 
                  sheet_name="PAT_POP_Estimated GFR result 30", 
                  header=3, 
                  usecols="A:D").iloc[:42]

# %%
s
# Out:
#               Value  Occurrences  Rule (to be defined by CCF team)  \
# 0               >60          117                             60.00
# 1                59            7                             59.00
# 2                55            6                             55.00
# 3                52            5                             52.00
# 4                46            4                             46.00
# 5                58            4                             58.00
# 6                54            3                             54.00
# 7                57            3                             57.00
# 8                45            2                             45.00
# 9                42            2                             42.00
# 10               13            2                             13.00
# 11               38            2                             38.00
# 12               60            2                             60.00
# 13               49            2                             49.00
# 14               36            2                             36.00
# 15               53            2                             53.00
# 16               40            2                             40.00
# 17               51            2                             51.00
# 18               29            2                             29.00
# 19               56            2                             56.00
# 20               48            2                             48.00
# 21                4            1                              4.00
# 22            54.29            1                             54.29
# 23               14            1                             14.00
# 24               21            1                             21.00
# 25  Greater than 60            1                             60.00
# 26               27            1                             27.00
# 27                8            1                              8.00
# 28               43            1                             43.00
# 29               28            1                             28.00
# 30            52.45            1                             52.45
# 31               33            1                             33.00
# 32               31            1                             31.00
# 33               41            1                             41.00
# 34               50            1                             50.00
# 35               30            1                             30.00
# 36               24            1                             24.00
# 37               47            1                             47.00
# 38               35            1                             35.00
# 39               37            1                             37.00
# 40            87.11            1                             87.11
#
#                      Add'l notes
# 0   Add 'imputation flag' column
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                            NaN
# 6                            NaN
# 7                            NaN
# 8                            NaN
# 9                            NaN
# 10                           NaN
# 11                           NaN
# 12                           NaN
# 13                           NaN
# 14                           NaN
# 15                           NaN
# 16                           NaN
# 17                           NaN
# 18                           NaN
# 19                           NaN
# 20                           NaN
# 21                           NaN
# 22                           NaN
# 23                           NaN
# 24                           NaN
# 25  Add 'imputation flag' column
# 26                           NaN
# 27                           NaN
# 28                           NaN
# 29                           NaN
# 30                           NaN
# 31                           NaN
# 32                           NaN
# 33                           NaN
# 34                           NaN
# 35                           NaN
# 36                           NaN
# 37                           NaN
# 38                           NaN
# 39                           NaN
# 40                           NaN
